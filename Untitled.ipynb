# %%
import pandas as pd

df = pd.read_csv("data/heart.csv")
print("Shape:", df.shape)
print("\nColumn names:")
print(list(df.columns))

print("\nFirst 5 rows:")
print(df.head())

print("\nInfo:")
df.info()

print("\nUnique values per column (quick look):")
for col in df.columns:
    uniques = df[col].unique()[:10]
    print(f"{col:15} → {len(df[col].unique())} unique, sample: {uniques}")
# Out:
# Shape: (297, 14)
#
# Column names:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'condition']
#
# First 5 rows:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ...

# %%
import pandas as pd

df = pd.read_csv("data/diabetes.csv")
print("Shape:", df.shape)
print("\nColumn names:")
print(list(df.columns))

print("\nFirst 5 rows:")
print(df.head())

print("\nInfo:")
df.info()

print("\nUnique values per column (quick look):")
for col in df.columns:
    uniques = df[col].unique()[:10]
    print(f"{col:15} → {len(df[col].unique())} unique, sample: {uniques}")
# Out:
# Shape: (768, 9)
#
# Column names:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
#
# First 5 rows:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# ...

# %%
import os
os.chdir("/Users/gaurav/hdi-uncertainty-dashboard")
# !pwd 

from src.load import load_pima
from sklearn.pipeline import Pipeline

X_train, X_val, X_test, y_train, y_val, y_test, pre = load_pima()

def pct(y): return f"{y.mean():.3f}"
print("Pima splits (rows):", len(X_train), len(X_val), len(X_test))
print("Pima pos rate (train/val/test):", pct(y_train), pct(y_val), pct(y_test))

pipe = Pipeline([("pre", pre)])
pipe.fit(X_train, y_train)
Xt = pipe.transform(X_train)
print("Pima transformed train shape:", Xt.shape)

# Quick NA audit after zero→NaN replacement (before imputer)
import pandas as pd
import numpy as np
import sys
print("\\nNA counts in training features (before imputation):")
print(pd.isna(X_train).sum().to_dict())
# Out:
# /Users/gaurav/hdi-uncertainty-dashboard
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 5
#       2 os.chdir("/Users/gaurav/hdi-uncertainty-dashboard")
#       3 get_ipython().system('pwd')
# ----> 5 from src.load import load_pima
#       6 from sklearn.pipeline import Pipeline
#       8 X_train, X_val, X_test, y_train, y_val, y_test, pre = load_pima()
#
# ImportError: cannot import name 'load_pima' from 'src.load' (/Users/gaurav/hdi-uncertainty-dashboard/src/load.py)
